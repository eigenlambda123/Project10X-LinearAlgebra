# %%
v = [1, 2, 3]
w = [4, 5]

a = [4, 2]
b = [-1, 2]

unit_vector_test = [1/2, 1/2, 1/2, 1/2]
unit_vector_test_2 = [1, 1]
unit_vector_test_3 = [1/math.sqrt(2), 1/math.sqrt(2)]

# %% [markdown]
# ### Lengths

# %%
import math

def calculate_length(vector):
    res =[]
    for v in range(len(vector)):
        res.append(vector[v]*vector[v])
    return round(math.sqrt(sum(res)), 2)

print(calculate_length(unit_vector_test_3))
# Out:
# 1.0

# %% [markdown]
# ### Unit Vector Checker

# %%
plot_vector_2d(unit_vector_test_3)


if length == 1:
    print("is a unit vector")
else:
    print("is not a unit vector")
# Out:
# is a unit vector
