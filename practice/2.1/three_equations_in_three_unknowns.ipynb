# %% [markdown]
# ## Solving a System of 3 Linear Equations in 3 Unknowns
#
# We want to visualize the solution of a linear system \( Ax = b \), where:
#
# - \( A \) is a 3×3 matrix representing coefficients
# - \( b \) is a vector of constants
# - \( x \) is the vector of unknowns \( [x, y, z] \)
#
# The goal is to find the point in 3D space where all three planes defined by the equations intersect.

# %% [markdown]
# ### The System:
#
#
# \begin{aligned}
# x + 2y + 3z &= 6 \\
# 2x + 5y + 2z &= 4 \\
# 6x - 3y + z &= 2
# \end{aligned}
#
#
# We are solving for values of \( x, y, z \) that satisfy all three equations at once.
# Since we have 3 equations and 3 unknowns, there is typically a unique solution (when the matrix is invertible).

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.lines import Line2D

# Define A and b
A = np.array([[1, 2, 3],
              [2, 5, 2],
              [6, -3, 1]])

b = np.array([6, 4, 2])

# Solve for intersection point
intersection = np.linalg.solve(A, b)
x0, y0, z0 = intersection

# Create 3D grid
x_vals = np.linspace(-10, 10, 20)
y_vals = np.linspace(-10, 10, 20)
X, Y = np.meshgrid(x_vals, y_vals)

def plane_z(a, b, c, d):
    return (d - a * X - b * Y) / c

# Plot setup
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

colors = ['red', 'green', 'blue']
labels = ['Plane 1', 'Plane 2', 'Plane 3']

# Plot each plane
for i in range(3):
    a, b_, c = A[i]
    d = b[i]
    Z = plane_z(a, b_, c, d)
    ax.plot_surface(X, Y, Z, alpha=0.6, color=colors[i])

# Plot the intersection point
ax.scatter(x0, y0, z0, color='black', s=80, label='Intersection Point')
ax.text(x0, y0, z0 + 1, f'({x0:.2f}, {y0:.2f}, {z0:.2f})', color='black')

# Axes labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Visualization of Ax = b\n(Three Planes Intersecting at One Point)')

# Custom legend
legend_elements = [Line2D([0], [0], color=colors[i], lw=4, label=labels[i]) for i in range(3)]
legend_elements.append(Line2D([0], [0], marker='o', color='w', label='Intersection',
                              markerfacecolor='black', markersize=10))
ax.legend(handles=legend_elements)

plt.show()

# %% [markdown]
# ## Interpretation
#
# - Each plane represents one of the three linear equations.
# - The black dot is the unique point where all three planes intersect.
# - This point is the solution to the system \( Ax = b \).
#
# Thus, this geometric intersection corresponds to the algebraic solution for \( x \), \( y \), and \( z \).
#
# * The answer in this case is (0, 0, 2), why? if you simply solve it Ax=b will be consistent, and in the visualization it is also shown that the three equation meet at a single point, and that single point is in (0, 0, 2), this is typically how Linear Equation works.
#
# * if we look at the bigger picture here and really think about our three Linear equations, we would see that any Linear combination of these columns can produce any vector `b`
