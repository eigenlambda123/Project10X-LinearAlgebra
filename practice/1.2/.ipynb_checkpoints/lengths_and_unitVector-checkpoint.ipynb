# %%
v = [1, 2, 3]
w = [4, 5]

a = [4, 2]
b = [-1, 2]

unit_vector_test = [1/2, 1/2, 1/2, 1/2]

# %% [markdown]
# ### Lengths

# %%
import math

def calculate_length(vector):
    res =[]
    for v in range(len(vector)):
        res.append(vector[v]*vector[v])
    return math.sqrt(sum(res))

print(calculate_length(v))
# Out:
# 3.7416573867739413

# %% [markdown]
# ### Unit Vector Checker

# %%
import matplotlib.pyplot as plt
def plot_vector(vector, origin=(0, 0), color='blue', label='Vector'):
    # Unpack the origin and the vector
    ox, oy = origin
    vx, vy = vector

    # Create the plot
    plt.figure()
    plt.quiver(ox, oy, vx, vy, angles='xy', scale_units='xy', scale=1, color=color, label=label)

    # Set limits a bit larger than vector components for better visibility
    limit = max(abs(vx), abs(vy), 1) + 1
    plt.xlim(-limit, limit)
    plt.ylim(-limit, limit)

    # Draw axes
    plt.axhline(0, color='gray', linewidth=0.5)
    plt.axvline(0, color='gray', linewidth=0.5)
    plt.grid(True)
    plt.gca().set_aspect('equal')
    plt.legend()
    plt.title('Single Vector in Cartesian Plane')
    plt.show()

# Example usage
v = [3, 2]
plot_vector(v)

# Example usage
length = calculate_length(unit_vector_test)
plot_single_vector(unit_vector_test)

if length == 1:
    print("is a unit vector")
else:
    print("is not a unit vector")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 31
#      29 # Example usage
#      30 length = calculate_length(unit_vector_test)
# ---> 31 plot_single_vector(unit_vector_test)
#      33 if length == 1:
#      34     print("is a unit vector")
#
# Cell In[18], line 5, in plot_single_vector(v, origin, color, label)
#       3 def plot_single_vector(v, origin=[0, 0], color='r', label='Vector'):
#       4     plt.figure()
# ----> 5     plt.quiver(*origin, *v, scale=1, color=color, label=label)
#       7     # Dynamically set limits based on vector length
#       8     max_val = max(abs(v[0]), abs(v[1]), 1)
#
# File ~\.virtualenvs\Project10X-Linear-Algebra-_WMxz4LY\Lib\site-packages\matplotlib\pyplot.py:3912, in quiver(data, *args, **kwargs)
#    3910 @_copy_docstring_and_deprecators(Axes.quiver)
#    3911 def quiver(*args, data=None, **kwargs) -> Quiver:
# ...
